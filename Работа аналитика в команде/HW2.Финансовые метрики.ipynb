# %% [markdown]
# 1. Сгруппируйте активы по степени их ликвидности, а пассивы — по срочности их погашения (см. таблицу).
# 2. Определите чистые активы и чистый оборотный капитал (NWC) на начало отчетного периода.
# 3. Рассчитайте коэффициенты, характеризующие ликвидность и платежеспособность данного предприятия на начало и конец отчетного периода.
# 4. Сделайте выводы о динамике финансового состояния организации

# %% [markdown]
# Статья баланса	На начало отчетного периода, тыс. руб.	На конец отчетного периода, тыс. руб.
#
# Основные средства	                    1820                   	2250
#
# Денежные средства                   	1258                   1104
#
# Запасы	2230	2450
#
# Дебиторская задолженность	560	610
#
# Нематериальные активы	152	174
#
# Долгосрочные финансовые вложения	90	110
#
# Незавершенное производство	134	157
#
# НДС к возврату	263	241
#
# Готовая продукция	236	573
#
# Краткосрочные финансовые вложения	70	89
#
# Уставный капитал	3465	3465
#
# Краткосрочные кредиты	1200	2545
#
# Нераспределенная прибыль	83	152
#
# Долгосрочные кредиты	370	730
#
# Краткосрочная кредиторка	1500	700
#
# Доходы будущих периодов	195	166

# %% [markdown]
# # 1.Сгруппируйте активы по степени их ликвидности, а пассивы — по срочности их погашения (см. таблицу).
#
# ## Активы
#
# ### А1 Наиболее ликвидные
#
# - Денежные средства ОА
# - Основные средства ВОА
# - Краткосрочные финансовые вложения ОА
# - НДС к возврату ОА
#
# ### А2 Быстро реализуемые
#
# - Дебиторская задолженность ОА
# - Долгосрочные финансовые вложения ОА
#
# ### А3 Медленно реализуемые
#
# - Готовая продукция ОА
# - Запасы ОА
# - Незавершенное производство ОА
# - Нематериальные активы ВОА
#
#
# ## Пассивы
#
# ### П1 Наиболее срочные пассивы
#
# - Краткосрочная кредиторка КО
# - Доходы будущих периодов ДБП
#
# ### П2 Среднесрочные обязательства
#
# - Краткосрочные кредиты КО
# - Нераспределенная прибыль
#
# ### П3 Долгосрочные обязательства
#
# - Долгосрочные кредиты ДО
#
# ### П4 Постоянные пассивы
#
# - Уставный капитал

# %% [markdown]
# # 2.Определите чистые активы и чистый оборотный капитал (NWC) на начало отчетного периода.
#
# Чистые активы = (ОА + ВОА - ЗУ - ЗВА) - (КО + ДО - ДБП)
#
# Чистые активы = (4841 + 1972 - 0) - (2700 + 370 - 195) = 3938
#
# Чистый оборотный капитал = ОА - КО
#
# Чистый оборотный капитал = 4841 - 2700 = 2141

# %% [markdown]
# # 3.Рассчитайте коэффициенты, характеризующие ликвидность и платежеспособность данного предприятия на начало и конец отчетного периода.
#
# Коэффициент ликвидности = Текущие активы / Текущие обязательства
# Коэффициент ликвидности на начало периода = ОА / КО = 4841 / 2700 = 1,79
# Коэффициент ликвидности на конец периода = ОА / КО = 5334 / 3245 = 1,64

# %% [markdown]
# # 4. Сделайте выводы о динамике финансового состояния организации
# Динамика коэффициента ликвидности, говорит о большем темпе увеличения краткосрочных обязательств, чем оборотных активов, что в дальнейшем может негативно сказаться на платежеспособности предприятия
#
# Коэффициент ликвидности существенно превышающий 1, говорит о неэффективности использования оборотных средств
